# %% [markdown]
# # Pandas = python library for data manipulation and analysis

# %% [markdown]
# ##Data frame, series, pandas

# %%
import pandas as pd

# %%
from pandas import ExcelWriter
from pandas import ExcelFile

data_frame = pd.read_excel('2004 Addendum.xlsx')

# %%
data_frame
# Out:
#                                       Asset description Unnamed: 1 Unnamed: 2  \
# 0         FIXED INCOME\nU.S. Securities Corporate Bonds        NaN        NaN
# 1                                         1st Data Corp        NaN        NaN
# 2                                    1st Un Corp Sub Nt        NaN        NaN
# 3                                     6 Flags Inc Sr Nt        NaN        NaN
# 4                                     6 Flags Inc Sr Nt        NaN        NaN
# ...                                                 ...        ...        ...
# 3459                             Total Commingled Funds        NaN        NaN
# 3460                   Less Estimated Disposition Costs        NaN        NaN
# 3461                                   Total Fair Value        NaN        NaN
# 3462  Total Portfolio                               ...        NaN        NaN
# 3463                                                NaN        NaN        NaN
#
# ...

# %% [markdown]
# 제일 위에서부터 데이터를 뽑아주는 head. 괄호 안에 숫자만큼 위에서부터 데이터를 가져옴
# 빈칸이면 5개까지만

# %%
data_frame.head(2)
# Out:
#                                Asset description Unnamed: 1 Unnamed: 2  \
# 0  FIXED INCOME\rU.S. Securities Corporate Bonds        NaN        NaN
# 1                                  1st Data Corp        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Interest Rate Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN           NaN        NaN
# 1        NaN        NaN        NaN        NaN        3.900%        NaN
#
#   Maturity date  ... Unnamed: 16   Cost Value Unnamed: 18 Unnamed: 19  \
# 0           NaN  ...         NaN          NaN         NaN         NaN
# 1    10/01/2009  ...         NaN  $ 3,304,704         NaN         NaN
#
#   Unnamed: 20 Unnamed: 21 Market Value Unnamed: 23 Unnamed: 24 Unnamed: 25
# 0         NaN         NaN          NaN         NaN         NaN         NaN
# 1         NaN         NaN  $ 3,297,399         NaN         NaN         NaN
#
# [2 rows x 26 columns]

# %% [markdown]
# 제일 아래에서부터 데이터를 뽑아주는 tail

# %%
data_frame.tail()
# Out:
#                                       Asset description Unnamed: 1 Unnamed: 2  \
# 3459                             Total Commingled Funds        NaN        NaN
# 3460                   Less Estimated Disposition Costs        NaN        NaN
# 3461                                   Total Fair Value        NaN        NaN
# 3462  Total Portfolio                               ...        NaN        NaN
# 3463                                                NaN        NaN        NaN
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Interest Rate Unnamed: 8  \
# 3459        NaN        NaN        NaN        NaN           NaN        NaN
# 3460        NaN        NaN        NaN        NaN           NaN        NaN
# 3461        NaN        NaN        NaN        NaN           NaN        NaN
# 3462        NaN        NaN        NaN        NaN           NaN        NaN
# 3463        NaN        NaN        NaN        NaN           NaN        NaN
#
# ...

# %% [markdown]
# ##data frame
# type(data_frame.[header이름])을 치면 type이 시리즈로 나옴. 즉 리스트!
# 그렇기에 각 시리즈들을 넣고 데이터 프레임을 넣으면 표 완성!

# %%
s1 = pd.core.series.Series ([1,2,3])

# %%
s2 = pd.core.series.Series (['one', 'two', 'three'])

# %%
pd.DataFrame(data=dict(num=s1, word=s2))
# Out:
#    num   word
# 0    1    one
# 1    2    two
# 2    3  three

# %% [markdown]
# ##파일에서 데이터 불러오기

# %% [markdown]
# ##pandas가 깔려있는지 확인하는 코드

# %%
! conda list | grep pandas
# Out:
# pandas                    0.25.1           py37h0a44026_0

# %%
df = pd.read_excel('2004 Addendum.xlsx')

# %%
df.head()
# Out:
#                                Asset description Unnamed: 1 Unnamed: 2  \
# 0  FIXED INCOME\nU.S. Securities Corporate Bonds        NaN        NaN
# 1                                  1st Data Corp        NaN        NaN
# 2                             1st Un Corp Sub Nt        NaN        NaN
# 3                              6 Flags Inc Sr Nt        NaN        NaN
# 4                              6 Flags Inc Sr Nt        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Interest Rate Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN           NaN        NaN
# 1        NaN        NaN        NaN        NaN         0.039        NaN
# 2        NaN        NaN        NaN        NaN        0.0655        NaN
# 3        NaN        NaN        NaN        NaN       0.09625        NaN
# 4        NaN        NaN        NaN        NaN        0.0975        NaN
#
#          Maturity date  ... Unnamed: 16 Cost Value Unnamed: 18 Unnamed: 19  \
# ...

# %%
#csv 파일인 경우 
df = pdf.read_csv('data/friend_list.csv', delimiter = '\t')

# %%
#txt 파일인 경우도 csv로 읽을 수 있음!
df = pdf.read_csv('data/friend_list.txt', delimiter = '\t')

# %%
#헤더가 없는 경우
df = pdf.read_csv('data/friend_list.csv', header = None)

# %%
#헤더를 새로 넣어주는 경우
df.columns = ['name', 'age', 'job']
df

# %%
#위의 코드를 한번에 쓰는 법
df = pd.read_csv('data/friend_list.csv', header = None, columns = ['name', 'age', 'job'])
df
